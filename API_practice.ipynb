# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the tuple() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,\
          citipy.nearest_city(coordinate[0], coordinate[1]).country_code)
# Out:
# mkushi zm
# kapaa us
# yahotyn ua
# rikitea pf
# vaini to
# hobart au
# bluff nz
# norman wells ca
# sao felix do xingu br
# mataura pf
# ushuaia ar
# severiano melo br
# the valley ai
# brandenburg de
# butaritari ki
# hermanus za
# jamestown sh
# wattegama lk
# ushuaia ar
# rikitea pf
# mataura pf
# abnub eg
# provideniya ru
# bluff nz
# belushya guba ru
# port alfred za
# new norfolk au
# vallenar cl
# carnarvon au
# ribeira grande pt
# hithadhoo mv
# porto walter br
# kunyang cn
# okhotsk ru
# atuona pf
# anan jp
# port alfred za
# khatanga ru
# nome us
# hasaki jp
# atuona pf
# kodiak us
# balabac ph
# luganville vu
# pevek ru
# bathsheba bb
# mar del plata ar
# rikitea pf
# luderitz na
# hilo us
# port elizabeth za
# amderma ru
# punta arenas cl
# grindavik is
# cherskiy ru
# ushuaia ar
# piacabucu br
# sambava mg
# norman wells ca
# luganville vu
# nikolskoye ru
# busselton au
# torbay ca
# airai pw
# ribeira grande pt
# arraial do cabo br
# quelimane mz
# rikitea pf
# bentiu sd
# bograd ru
# mudigere in
# tsihombe mg
# atuona pf
# amderma ru
# locri it
# saint-philippe re
# upernavik gl
# cape town za
# port alfred za
# shieli kz
# rikitea pf
# arroyo us
# mataura pf
# tabiauea ki
# rikitea pf
# mataura pf
# sao filipe cv
# pangnirtung ca
# nanortalik gl
# barrow us
# taolanaro mg
# chokurdakh ru
# katha mm
# uray ru
# vaitupu wf
# vaini to
# bredasdorp za
# castro cl
# sao joao da barra br
# faanui pf
# avarua ck
# busselton au
# albany au
# jaciara br
# ushuaia ar
# mgandu tz
# atuona pf
# penzance gb
# san patricio mx
# owando cg
# hornepayne ca
# areia branca br
# meulaboh id
# ilulissat gl
# salalah om
# busselton au
# busselton au
# areia branca br
# lopatino ru
# hamilton bm
# busselton au
# punta arenas cl
# tasiilaq gl
# atuona pf
# los llanos de aridane es
# avarua ck
# bluff nz
# itarema br
# hermanus za
# cayenne gf
# nyurba ru
# isangel vu
# khatanga ru
# bathsheba bb
# atuona pf
# mar del plata ar
# georgetown sh
# tuktoyaktuk ca
# manresa es
# albany au
# saleaula ws
# vaini to
# kodiak us
# saskylakh ru
# bredasdorp za
# klaksvik fo
# sinop tr
# tual id
# albany au
# punta arenas cl
# rikitea pf
# illoqqortoormiut gl
# grindavik is
# victoria sc
# longyearbyen sj
# rocha uy
# taolanaro mg
# broome au
# buraydah sa
# samaipata bo
# mar del plata ar
# doha qa
# avarua ck
# suntar ru
# busselton au
# iqaluit ca
# upernavik gl
# labrea br
# chapais ca
# rosarito mx
# puerto ayora ec
# burbach de
# rio gallegos ar
# talcahuano cl
# valdepenas es
# kodiak us
# iqaluit ca
# jambi id
# yaring th
# mataura pf
# anadyr ru
# hasaki jp
# bambous virieux mu
# georgetown sh
# luderitz na
# sioux lookout ca
# ust-nera ru
# provideniya ru
# vigrestad no
# rikitea pf
# anshun cn
# carnarvon au
# sindor ru
# sorvag fo
# vaini to
# rikitea pf
# ushuaia ar
# jamestown sh
# rikitea pf
# utiroa ki
# rikitea pf
# kaitangata nz
# yar-sale ru
# ushuaia ar
# taolanaro mg
# yellowknife ca
# saldanha za
# punta arenas cl
# brandfort za
# vila vu
# clyde river ca
# mount isa au
# rikitea pf
# barrow us
# marcona pe
# pochutla mx
# saint-georges gf
# albany au
# ust-kamchatsk ru
# grand river south east mu
# yining cn
# port alfred za
# jumla np
# rapid valley us
# cape town za
# kudat my
# quimperle fr
# naze jp
# chabahar ir
# vaini to
# matara lk
# portland au
# belushya guba ru
# vardo no
# nanortalik gl
# vaini to
# hilo us
# port hardy ca
# port alfred za
# barentsburg sj
# sentyabrskiy ru
# nikolskoye ru
# maragogi br
# vaini to
# castro cl
# algeciras ph
# ennis us
# alotau pg
# whyalla au
# the valley ai
# aklavik ca
# rikitea pf
# ushuaia ar
# hermanus za
# mpraeso gh
# ushuaia ar
# baijiantan cn
# atuona pf
# cape town za
# bubaque gw
# punta arenas cl
# mataura pf
# longyearbyen sj
# rikitea pf
# port hardy ca
# saint-philippe re
# georgetown sh
# yellowknife ca
# chokurdakh ru
# tuatapere nz
# dudinka ru
# port alfred za
# vadakku valliyur in
# chapais ca
# erenhot cn
# port alfred za
# ushuaia ar
# cherskiy ru
# chokurdakh ru
# ushuaia ar
# sao filipe cv
# dikson ru
# samusu ws
# ulladulla au
# omboue ga
# puerto rondon co
# riberalta bo
# attawapiskat ca
# tuktoyaktuk ca
# arraial do cabo br
# souillac mu
# hobart au
# palmer us
# barrow us
# bluff nz
# komono jp
# cherskiy ru
# anchorage us
# baykit ru
# marsa matruh eg
# gunjur gm
# bredasdorp za
# vestmannaeyjar is
# ribeira grande pt
# lebu cl
# bowen au
# fayaoue nc
# tumannyy ru
# nikolskoye ru
# sao filipe cv
# khatanga ru
# rawson ar
# bluff nz
# bluff nz
# broken hill au
# amderma ru
# mataura pf
# bargarh in
# taolanaro mg
# barrow us
# jamestown sh
# chuy uy
# churapcha ru
# salsig ro
# aklavik ca
# hermanus za
# bredasdorp za
# erzin ru
# mys shmidta ru
# nouakchott mr
# vaini to
# torbay ca
# rocha uy
# mataura pf
# punta arenas cl
# albany au
# tocopilla cl
# new norfolk au
# arraial do cabo br
# punta arenas cl
# arraial do cabo br
# oum hadjer td
# saskylakh ru
# touros br
# avarua ck
# maningrida au
# anuradhapura lk
# clyde river ca
# chokurdakh ru
# illoqqortoormiut gl
# upernavik gl
# padang id
# atuona pf
# talnakh ru
# jinchang cn
# bassar tg
# saleaula ws
# vaini to
# ancud cl
# avarua ck
# konevo ru
# severo-kurilsk ru
# ancud cl
# busselton au
# haines junction ca
# nanortalik gl
# jamestown sh
# mataura pf
# grimshaw ca
# barentsburg sj
# balezino ru
# katsuura jp
# vila franca do campo pt
# georgetown gy
# vila velha br
# vaini to
# mocambique mz
# mustafakemalpasa tr
# riyadh sa
# katsuura jp
# thompson ca
# nikolskoye ru
# sutton ca
# wenling cn
# butaritari ki
# te anau nz
# mataura pf
# kassala sd
# meulaboh id
# sao domingos do maranhao br
# mar del plata ar
# alta floresta br
# mozirje si
# arraial do cabo br
# mataura pf
# ottawa us
# klyuchi ru
# hithadhoo mv
# arraial do cabo br
# coihaique cl
# dinsor so
# jamestown sh
# victoria sc
# batagay-alyta ru
# barrow us
# weihai cn
# kearney us
# harlingen nl
# nizwa om
# saskylakh ru
# castro cl
# saint-philippe re
# cabo san lucas mx
# new norfolk au
# nouadhibou mr
# tromso no
# mobai sl
# lebu cl
# genhe cn
# punta arenas cl
# bluff nz
# khatanga ru
# soe id
# tuktoyaktuk ca
# vertientes cu
# taolanaro mg
# lishui cn
# marawi sd
# fort saint john ca
# natal br
# atuona pf
# te anau nz
# rabo de peixe pt
# abha sa
# mataura pf
# hermanus za
# qaanaaq gl
# santa lucia es
# bluff nz
# belmonte br
# thiers fr
# bluff nz
# hithadhoo mv
# saint george bm
# krasnogvardeyskiy ru
# bluff nz
# grand river south east mu
# carutapera br
# port elizabeth za
# kolpny ru
# upernavik gl
# chuy uy
# saint-pierre re
# chokurdakh ru
# zunyi cn
# thompson ca
# husavik is
# kegayli uz
# sitka us
# busselton au
# mar del plata ar
# thompson ca
# punta arenas cl
# cherskiy ru
# butaritari ki
# phan thiet vn
# araouane ml
# hilo us
# basoko cd
# yellowknife ca
# pevek ru
# mataura pf
# mahebourg mu
# mataura pf
# jamestown sh
# vaitupu wf
# rikitea pf
# ancud cl
# iqaluit ca
# hobart au
# puerto ayora ec
# ushuaia ar
# cabo san lucas mx
# anuradhapura lk
# jamestown sh
# mataura pf
# torbay ca
# bambous virieux mu
# atuona pf
# yellowknife ca
# puerto ayora ec
# mehamn no
# san cristobal ec
# hit iq
# vaini to
# mataura pf
# taolanaro mg
# hermanus za
# hilo us
# lensk ru
# burica pa
# east london za
# swift current ca
# illoqqortoormiut gl
# ushuaia ar
# punta arenas cl
# kahului us
# neustadt de
# taolanaro mg
# tuatapere nz
# tuktoyaktuk ca
# dunda tz
# ushuaia ar
# taltal cl
# kapaa us
# rikitea pf
# busselton au
# new norfolk au
# hasaki jp
# albany au
# xai-xai mz
# mar del plata ar
# sorvag fo
# jurbarkas lt
# port alfred za
# belushya guba ru
# port hardy ca
# bengkulu id
# villaviciosa es
# punta arenas cl
# puerto ayora ec
# mataura pf
# svetlogorsk ru
# conceicao do araguaia br
# broken hill au
# lebu cl
# awjilah ly
# cockburn town tc
# hay river ca
# kapaa us
# punta arenas cl
# belushya guba ru
# punta arenas cl
# east london za
# puerto ayora ec
# rikitea pf
# mys shmidta ru
# riyadh sa
# kenai us
# ushuaia ar
# murdochville ca
# new norfolk au
# jamestown sh
# illoqqortoormiut gl
# paamiut gl
# cayenne gf
# krasnoselkup ru
# bartow us
# rikitea pf
# albany au
# sioux lookout ca
# ostrovnoy ru
# novikovo ru
# viesca mx
# mataura pf
# constitucion mx
# castro cl
# punta arenas cl
# mahebourg mu
# atuona pf
# ushuaia ar
# sembe cg
# buon me thuot vn
# qaanaaq gl
# bluff nz
# kapaa us
# ushuaia ar
# illoqqortoormiut gl
# rikitea pf
# saint-philippe re
# busselton au
# rikitea pf
# mancio lima br
# kieta pg
# vestmannaeyjar is
# albany au
# mataura pf
# lyubim ru
# okhotsk ru
# esperance au
# soc trang vn
# taolanaro mg
# qaanaaq gl
# lagoa pt
# khatanga ru
# hermanus za
# longyearbyen sj
# rikitea pf
# shitkino ru
# port jervis us
# atuona pf
# san vicente ph
# hermanus za
# cape town za
# takoradi gh
# vaini to
# hamilton bm
# georgetown sh
# albany au
# illoqqortoormiut gl
# hobart au
# hilo us
# meulaboh id
# brigham city us
# cabo san lucas mx
# nikolskoye ru
# tsihombe mg
# bluff nz
# illoqqortoormiut gl
# punta arenas cl
# hobyo so
# barentsburg sj
# vaini to
# viligili mv
# tuktoyaktuk ca
# melo uy
# banfora bf
# saskylakh ru
# punta arenas cl
# longyearbyen sj
# constitucion cl
# taolanaro mg
# mar del plata ar
# viedma ar
# taolanaro mg
# amarkantak in
# punta arenas cl
# arraial do cabo br
# east london za
# port lincoln au
# ribeira grande pt
# rikitea pf
# herat af
# butaritari ki
# makakilo city us
# mataura pf
# pascagoula us
# butembo cd
# carnarvon au
# talcahuano cl
# verkhoyansk ru
# port augusta au
# cape town za
# nome us
# palabuhanratu id
# saint george bm
# bluff nz
# punta arenas cl
# dekernes eg
# atambua id
# whitianga nz
# salinopolis br
# qaanaaq gl
# mataura pf
# mount gambier au
# iqaluit ca
# jamestown sh
# sabancuy mx
# kavaratti in
# tavricheskoye ru
# rikitea pf
# road town vg
# lincoln nz
# kahului us
# thompson ca
# ouegoa nc
# khatanga ru
# mataura pf
# isangel vu
# busselton au
# hasaki jp
# gawler au
# atuona pf
# ushuaia ar
# avarua ck
# broome au
# ugoofaaru mv
# ust-maya ru
# rawson ar
# punta arenas cl
# bay saint louis us
# ushuaia ar
# hobart au
# that phanom th
# mar del plata ar
# khandyga ru
# rikitea pf
# carnarvon au
# husavik is
# taolanaro mg
# hilo us
# vila velha br
# mataura pf
# margate za
# hermanus za
# gunjur gm
# kapaa us
# sao filipe cv
# airai pw
# bethel us
# khatanga ru
# hobart au
# dikson ru
# new norfolk au
# mataura pf
# lac du bonnet ca
# atuona pf
# longyearbyen sj
# chuy uy
# saint george bm
# ushuaia ar
# maniitsoq gl
# pisco pe
# port lincoln au
# kavieng pg
# port alfred za
# regente feijo br
# punta arenas cl
# kommunisticheskiy ru
# reus es
# yulara au
# hovd mn
# port alfred za
# ribeira grande pt
# kodiak us
# busselton au
# bredasdorp za
# tual id
# carnarvon au
# nanortalik gl
# albany au
# winnemucca us
# diego de almagro cl
# victoria sc
# punta arenas cl
# kapaa us
# victoria sc
# bredasdorp za
# sao filipe cv
# shingu jp
# dingle ie
# bredasdorp za
# arti ru
# santo antonio do leverger br
# carnarvon au
# san patricio mx
# bluff nz
# vila do maio cv
# vaini to
# ushuaia ar
# cape town za
# ponta do sol cv
# shakawe bw
# belmonte br
# carnarvon au
# vanavara ru
# bilibino ru
# nemuro jp
# adrar dz
# dubbo au
# castro cl
# yicheng cn
# cherskiy ru
# hilo us
# taolanaro mg
# omboue ga
# fernie ca
# bluff nz
# laguna br
# qaanaaq gl
# bredasdorp za
# sampit id
# shanhetun cn
# tutoia br
# ascension bo
# arraial do cabo br
# wattegama lk
# meyungs pw
# gayny ru
# castro cl
# perelyub ru
# portland au
# butaritari ki
# grand river south east mu
# marcona pe
# busselton au
# ushuaia ar
# okhotsk ru
# torbay ca
# arraial do cabo br
# mataura pf
# east london za
# mayo ca
# albany au
# walvis bay na
# albany au
# jalu ly
# olafsvik is
# rikitea pf
# swan hill au
# touros br
# butaritari ki
# mwense zm
# novyy urengoy ru
# mataura pf
# cape town za
# shelburne ca
# new norfolk au
# hermanus za
# suluq ly
# arraial do cabo br
# punta arenas cl
# warqla dz
# ponta do sol cv
# busselton au
# bluff nz
# kandalaksha ru
# kattivakkam in
# victoria sc
# ushuaia ar
# mataura pf
# hilo us
# trelew ar
# vaini to
# high level ca
# isiro cd
# arraial do cabo br
# tsihombe mg
# moanda ga
# kabelvag no
# ambulu id
# bilibino ru
# lagoa pt
# alice town bs
# jamestown sh
# gravdal no
# chokurdakh ru
# yarmouth ca
# agadez ne
# jamestown sh
# wieliczka pl
# jamestown sh
# saldanha za
# vaini to
# aklavik ca
# saraipali in
# saskylakh ru
# rio gallegos ar
# mount isa au
# chimbote pe
# san jose gt
# taolanaro mg
# kununurra au
# cape town za
# barentsburg sj
# airai pw
# russell nz
# san rafael ar
# rikitea pf
# tateyama jp
# bonavista ca
# georgetown sh
# rabaul pg
# tuktoyaktuk ca
# kaitangata nz
# chokurdakh ru
# chaozhou cn
# busselton au
# saint-philippe re
# saint-philippe re
# ushuaia ar
# teya ru
# plonsk pl
# lasa cn
# jamestown sh
# otjimbingwe na
# grand gaube mu
# cidreira br
# punta arenas cl
# bluefields ni
# dikson ru
# tuktoyaktuk ca
# qasigiannguit gl
# albany au
# kodiak us
# mokhsogollokh ru
# inirida co
# hermanus za
# pervoavgustovskiy ru
# codajas br
# tsihombe mg
# hohhot cn
# dikson ru
# shchelyayur ru
# kaifeng cn
# barrow us
# hilo us
# lebu cl
# inuvik ca
# vaini to
# luderitz na
# toliary mg
# busselton au
# barrow us
# kodiak us
# maldonado uy
# bluff nz
# cape town za
# atuona pf
# luanda ao
# tasiilaq gl
# mataura pf
# swan hill au
# namibe ao
# victoria sc
# houma us
# santa ana mx
# jamestown sh
# itaituba br
# borogontsy ru
# atuona pf
# ponta do sol cv
# mataura pf
# esperance au
# mount isa au
# amazar ru
# jamestown sh
# severo-kurilsk ru
# revda ru
# vaitupu wf
# barentsburg sj
# anchorage us
# rikitea pf
# tuy hoa vn
# sitka us
# tomigusuku jp
# new norfolk au
# taolanaro mg
# santa maria cv
# ancud cl
# punta arenas cl
# avarua ck
# punta arenas cl
# albany au
# arraial do cabo br
# cayenne gf
# ust-uda ru
# fortuna us
# oxelosund se
# baoying cn
# hermanus za
# ust-kamchatsk ru
# tumannyy ru
# kupang id
# bubaque gw
# tautira pf
# rudbar af
# asind in
# nanortalik gl
# rikitea pf
# chihuahua mx
# lebu cl
# sao joao da barra br
# manica mz
# luderitz na
# dingle ie
# saint-francois gp
# chuy uy
# warqla dz
# lorengau pg
# georgetown sh
# hithadhoo mv
# nizhneyansk ru
# rassvet ru
# perama gr
# airai pw
# nador ma
# tasiilaq gl
# sao filipe cv
# goderich sl
# lolua tv
# chuy uy
# san andres co
# khatanga ru
# lebu cl
# taolanaro mg
# bambous virieux mu
# bathsheba bb
# port elizabeth za
# fallon us
# mataura pf
# taolanaro mg
# bull savanna jm
# atuona pf
# georgetown sh
# zlatoustovsk ru
# presidencia roque saenz pena ar
# cabo san lucas mx
# mount gambier au
# porto velho br
# severo-kurilsk ru
# kapaa us
# husavik is
# igrim ru
# busselton au
# ushuaia ar
# narsaq gl
# atuona pf
# avarua ck
# los llanos de aridane es
# semey kz
# yulara au
# palabuhanratu id
# abu dhabi ae
# bluff nz
# ilulissat gl
# busselton au
# coquimbo cl
# mchinji mw
# nikolskoye ru
# mataura pf
# bijie cn
# carutapera br
# port alfred za
# lasa cn
# sitka us
# kavaratti in
# port elizabeth za
# salalah om
# weyburn ca
# ostrovnoy ru
# novska hr
# tabory ru
# busselton au
# hermanus za
# rokytne ua
# illoqqortoormiut gl
# provideniya ru
# saint-paul re
# cape town za
# atuona pf
# zaysan kz
# mys shmidta ru
# omaruru na
# ust-ishim ru
# namibe ao
# tasiilaq gl
# gandajika cd
# albany au
# benguela ao
# mahebourg mu
# hofn is
# busselton au
# cape town za
# urbano santos br
# ahar ir
# naze jp
# kosonsoy uz
# ponta do sol cv
# punta arenas cl
# hithadhoo mv
# ribeira grande pt
# ilulissat gl
# pisco pe
# adrar dz
# belaya gora ru
# new norfolk au
# cape town za
# albany au
# atuona pf
# taolanaro mg
# lasa cn
# alyangula au
# zheleznodorozhnyy ru
# nebaj gt
# buala sb
# karkaralinsk kz
# bubaque gw
# broken hill au
# bluff nz
# quatre cocos mu
# kharitonovo ru
# punta arenas cl
# chulman ru
# piranhas br
# albany au
# lebu cl
# barentsburg sj
# cidreira br
# taganak ph
# mareeba au
# lorengau pg
# leshukonskoye ru
# rikitea pf
# ushuaia ar
# vaini to
# taolanaro mg
# kaitangata nz
# kodiak us
# nasirabad pk
# hobart au
# upernavik gl
# strezhevoy ru
# maniitsoq gl
# ushuaia ar
# hami cn
# pangnirtung ca
# illoqqortoormiut gl
# emerald au
# roald no
# bluff nz
# saint-pierre pm
# punta arenas cl
# ceres za
# chagda ru
# tuktoyaktuk ca
# port blair in
# krasnoselkup ru
# oistins bb
# norman wells ca
# atuona pf
# maniitsoq gl
# kapaa us
# port alfred za
# port shepstone za
# kapaa us
# cabo san lucas mx
# port alfred za
# albany au
# punta arenas cl
# port alfred za
# lasa cn
# vaini to
# atbasar kz
# hithadhoo mv
# atuona pf
# kapaa us
# iberia pe
# saint anthony ca
# port alfred za
# ferme-neuve ca
# mataura pf
# hithadhoo mv
# mar del plata ar
# kavieng pg
# mukhen ru
# hilo us
# belushya guba ru
# bandarbeyla so
# salalah om
# kutum sd
# hermanus za
# tuktoyaktuk ca
# amderma ru
# ciudad bolivar ve
# hermanus za
# busselton au
# vaini to
# jamestown sh
# bredasdorp za
# punta arenas cl
# busselton au
# mogadishu so
# wiang sa th
# shirokiy ru
# vaitupu wf
# ribeira grande pt
# esik kz
# dunedin nz
# east london za
# barrow us
# cacahoatan mx
# ilulissat gl
# adrar dz
# kharp ru
# kapiri mposhi zm
# udachnyy ru
# arman ru
# udalguri in
# rikitea pf
# nanortalik gl
# arawa pg
# kapaa us
# ushuaia ar
# nisia floresta br
# caibarien cu
# kaura namoda ng
# lebu cl
# vaini to
# hambantota lk
# avarua ck
# upernavik gl
# chalus ir
# illoqqortoormiut gl
# punta arenas cl
# torbay ca
# arman ru
# champerico gt
# coquimbo cl
# yulara au
# barrow us
# samusu ws
# kouroussa gn
# nuuk gl
# kapaa us
# busselton au
# guerrero negro mx
# vaini to
# saint-philippe re
# morehead pg
# esperance au
# camacupa ao
# fortuna us
# ancud cl
# imperial us
# port alfred za
# sanchor in
# buala sb
# atuona pf
# victoria sc
# port alfred za
# arraial do cabo br
# hermanus za
# hobyo so
# norman wells ca
# belushya guba ru
# east london za
# provideniya ru
# vaini to
# baturite br
# kodiak us
# bluff nz
# hobart au
# punta arenas cl
# illoqqortoormiut gl
# illoqqortoormiut gl
# husavik is
# grindavik is
# dingle ie
# cape town za
# lavrentiya ru
# north bend us
# kahului us
# stavern no
# grand river south east mu
# busselton au
# rikitea pf
# airai pw
# carnarvon au
# mataura pf
# tuktoyaktuk ca
# imbituba br
# palestine us
# dikson ru
# hermanus za
# ushuaia ar
# naryan-mar ru
# mahebourg mu
# hilo us
# butaritari ki
# lircay pe
# busselton au
# sao gabriel da cachoeira br
# caravelas br
# poum nc
# sitka us
# ahuimanu us
# cherskiy ru
# barrow us
# cascais pt
# novobirilyussy ru
# dolinsk ru
# zalantun cn
# atuona pf
# punta arenas cl
# vaini to
# tuktoyaktuk ca
# tias es
# vaini to
# avarua ck
# bluff nz
# bluff nz
# basco ph
# mys shmidta ru
# dikson ru
# bud no
# narsaq gl
# samusu ws
# ambikapur in
# winston us
# normandin ca
# saint-pierre re
# mataura pf
# avarua ck
# voi ke
# salalah om
# kirakira sb
# rikitea pf
# kaili cn
# ulaanbaatar mn
# castro cl
# kavieng pg
# ningyang cn
# new norfolk au
# saint-denis re
# tiksi ru
# rikitea pf
# yinchuan cn
# isangel vu
# vitim ru
# hobart au
# doba td
# illoqqortoormiut gl
# palabuhanratu id
# tosham in
# punta arenas cl
# zhangjiakou cn
# rikitea pf
# sinnamary gf
# ostrovnoy ru
# bluff nz
# kapaa us
# santiago pe
# tasiilaq gl
# podor sn
# port alfred za
# araouane ml
# jamestown sh
# illoqqortoormiut gl
# albany au
# kapaa us
# batagay ru
# cherskiy ru
# busselton au
# rikitea pf
# rikitea pf
# ponta do sol cv
# taolanaro mg
# talnakh ru
# padang id
# belushya guba ru
# jaguarari br
# cape town za
# rikitea pf
# tasiilaq gl
# kodiak us
# georgetown sh
# saldanha za
# voh nc
# punta arenas cl
# new norfolk au
# port alfred za
# rosarito mx
# mitsamiouli km
# port alfred za
# east london za
# bethel us
# arraial do cabo br
# laguna br
# adrar dz
# punta arenas cl
# kantunilkin mx
# saskylakh ru
# ushuaia ar
# arraial do cabo br
# ushuaia ar
# tuktoyaktuk ca
# sarh td
# hermanus za
# kapaa us
# hermanus za
# nyaunglebin mm
# skibbereen ie
# artyk ru
# mlowo tz
# saint-philippe re
# port alfred za
# mombetsu jp
# anloga gh
# coquimbo cl
# mount isa au
# busselton au
# codrington ag
# mahebourg mu
# tiznit ma
# longyearbyen sj
# cape town za
# yellowknife ca
# hvide sande dk
# kapaa us
# dingle ie
# itupiranga br
# rikitea pf
# hermanus za
# poltavka ru
# vaini to
# buariki ki
# rikitea pf
# san quintin mx
# lebu cl
# one hundred mile house ca
# avarua ck
# leningradskiy ru
# hermanus za
# lompoc us
# new norfolk au
# taolanaro mg
# kendari id
# champerico gt
# rikitea pf
# hobart au
# georgetown sh
# isangel vu
# saldanha za
# ilembo tz
# albany au
# rikitea pf
# avarua ck
# taolanaro mg
# khatanga ru
# dicabisagan ph
# skalistyy ru
# lorengau pg
# georgetown sh
# yellowknife ca
# castro cl
# costa rica br
# steamboat springs us
# dakar sn
# sisimiut gl
# jamestown sh
# kapaa us
# skagastrond is
# tsihombe mg
# sturgis us
# bluff nz
# mayachnyy ru
# ziarat pk
# mar del plata ar
# ushuaia ar
# faanui pf
# yellowknife ca
# carnarvon au
# bakchar ru
# sibu my
# atuona pf
# mataura pf
# boa vista br
# barrow us
# lebu cl
# nikel ru
# khandagayty ru
# dunedin nz
# kuche cn
# taolanaro mg
# pahrump us
# busselton au
# te anau nz
# vao nc
# praia cv
# manta ec
# new norfolk au
# ushuaia ar
# cherskiy ru
# sentyabrskiy ru
# naze jp
# lebu cl
# carnarvon au
# darnah ly
# tuktoyaktuk ca
# garissa ke
# cherskiy ru
# palana ru
# kiruna se
# grand baie mu
# harper lr
# busselton au
# kamenskoye ru
# wetaskiwin ca
# saint-philippe re
# nikolskoye ru
# ushuaia ar
# margate za
# mataura pf
# fairbanks us
# namatanai pg
# chicama pe
# new norfolk au
# torbay ca
# port augusta au

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 635

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ebb567adef4f29d05b12f4eb73ccb415

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ebb567adef4f29d05b12f4eb73ccb415&q=Boston

# %%
# Make a 'Get' request for the city weather.
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Bston"
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [404]>

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# Get the text of the 'Get' request.
city_weather.text
# Out:
# '{"coord":{"lon":-71.0598,"lat":42.3584},"weather":[{"id":804,"main":"Clouds","description":"overcast clouds","icon":"04d"}],"base":"stations","main":{"temp":45.86,"feels_like":44.08,"temp_min":34.81,"temp_max":52.14,"pressure":1010,"humidity":86},"visibility":10000,"wind":{"speed":4,"deg":234,"gust":10},"clouds":{"all":90},"dt":1638454278,"sys":{"type":2,"id":2013408,"country":"US","sunrise":1638446117,"sunset":1638479558},"timezone":-18000,"id":4930956,"name":"Boston","cod":200}'

# %%
# Get the JSON text of the 'Get' request.
city_weather.json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04d'}],
#  'base': 'stations',
#  'main': {'temp': 45.86,
#   'feels_like': 44.08,
#   'temp_min': 34.81,
#   'temp_max': 52.14,
#   'pressure': 1010,
#   'humidity': 86},
#  'visibility': 10000,
#  'wind': {'speed': 4, 'deg': 234, 'gust': 10},
#  'clouds': {'all': 90},
#  'dt': 1638454278,
#  'sys': {'type': 2,
#   'id': 2013408,
#   'country': 'US',
#   'sunrise': 1638446117,
#   'sunset': 1638479558},
#  'timezone': -18000,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
if city_weather.status_code == 200:
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
# Out:
# City Weather found.

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Bston"
city_weather = requests.get(city_url)
if city_weather.status_code == 200:
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
# Out:
# City weather not found.

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather.json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04d'}],
#  'base': 'stations',
#  'main': {'temp': 45.86,
#   'feels_like': 44.08,
#   'temp_min': 34.81,
#   'temp_max': 52.14,
#   'pressure': 1010,
#   'humidity': 86},
#  'visibility': 10000,
#  'wind': {'speed': 4, 'deg': 234, 'gust': 10},
#  'clouds': {'all': 90},
#  'dt': 1638454278,
#  'sys': {'type': 2,
#   'id': 2013408,
#   'country': 'US',
#   'sunrise': 1638446117,
#   'sunset': 1638479558},
#  'timezone': -18000,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Get the JSON data.
boston_data = city_weather.json()

# %%
boston_data['sys']
# Out:
# {'type': 2,
#  'id': 2013408,
#  'country': 'US',
#  'sunrise': 1638446117,
#  'sunset': 1638479558}

# %%
lat = boston_data["coord"]["lat"]
lng = boston_data["coord"]["lon"]
max_temp = boston_data["main"]["temp_max"]
humidity = boston_data["main"]["humidity"]
clouds = boston_data["clouds"]["all"]
wind = boston_data["wind"]["speed"]
print(lat, lng, max_temp, humidity, clouds, wind)
# Out:
# 42.3584 -71.0598 52.14 86 90 4

# %%
# Import the datetime module from the datetime library.
from datetime import datetime
# Get the date from the JSON file.
date = boston_data["dt"]
# Convert the UTC date to a date format with year, month, day, hours, minutes, and seconds.
datetime.utcfromtimestamp(date)
# Out:
# datetime.datetime(2021, 12, 2, 14, 11, 18)

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
#Create an empty list to hold the weather data
city_data = []

#Print the beginning of the logging
print("Beginning Data Retrieval     ")
print("-----------------------------")

#Create counters
record_count = 1
set_count = 1

#Loop through all the cities in our list
for i, city in enumerate(cities):
    
    #Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    #Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
    #Log the URL, record, and set numbers and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    #Add 1 toS the record count
    record_count += 1

  # Run an API request for each of the cities. 

    try:
        #Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        #Parse out the needed data
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        #Convert the date to ISO standard
        city_date = datetime.utcfromtimestamp(city_weather['dt']).strftime('%Y-%m-%d %H:%M:%S')
        #Append the city information into city_data list
        city_data.append({'City': city.title(),
                          'Lat': city_lat, 
                          'Lng': city_lng, 
                          'Max Temp': city_max_temp, 
                          'Humidity': city_humidity, 
                          'Cloudiness': city_clouds, 
                          'Wind Speed': city_wind, 
                          'Country': city_country, 
                          'Date': city_date})
#If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

#Indicate that the Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mkushi
# Processing Record 2 of Set 1 | kapaa
# Processing Record 3 of Set 1 | yahotyn
# Processing Record 4 of Set 1 | rikitea
# Processing Record 5 of Set 1 | vaini
# Processing Record 6 of Set 1 | hobart
# Processing Record 7 of Set 1 | bluff
# Processing Record 8 of Set 1 | norman wells
# Processing Record 9 of Set 1 | sao felix do xingu
# Processing Record 10 of Set 1 | mataura
# Processing Record 11 of Set 1 | ushuaia
# Processing Record 12 of Set 1 | severiano melo
# Processing Record 13 of Set 1 | the valley
# Processing Record 14 of Set 1 | brandenburg
# Processing Record 15 of Set 1 | butaritari
# Processing Record 16 of Set 1 | hermanus
# Processing Record 17 of Set 1 | jamestown
# Processing Record 18 of Set 1 | wattegama
# Processing Record 19 of Set 1 | abnub
# Processing Record 20 of Set 1 | provideniya
# Processing Record 21 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 22 of Set 1 | port alfred
# Processing Record 23 of Set 1 | new norfolk
# Processing Record 24 of Set 1 | vallenar
# Processing Record 25 of Set 1 | carnarvon
# Processing Record 26 of Set 1 | ribeira grande
# Processing Record 27 of Set 1 | hithadhoo
# Processing Record 28 of Set 1 | porto walter
# Processing Record 29 of Set 1 | kunyang
# Processing Record 30 of Set 1 | okhotsk
# Processing Record 31 of Set 1 | atuona
# Processing Record 32 of Set 1 | anan
# Processing Record 33 of Set 1 | khatanga
# Processing Record 34 of Set 1 | nome
# Processing Record 35 of Set 1 | hasaki
# Processing Record 36 of Set 1 | kodiak
# Processing Record 37 of Set 1 | balabac
# Processing Record 38 of Set 1 | luganville
# Processing Record 39 of Set 1 | pevek
# Processing Record 40 of Set 1 | bathsheba
# Processing Record 41 of Set 1 | mar del plata
# Processing Record 42 of Set 1 | luderitz
# Processing Record 43 of Set 1 | hilo
# Processing Record 44 of Set 1 | port elizabeth
# Processing Record 45 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 46 of Set 1 | punta arenas
# Processing Record 47 of Set 1 | grindavik
# Processing Record 48 of Set 1 | cherskiy
# Processing Record 49 of Set 1 | piacabucu
# Processing Record 50 of Set 1 | sambava
# Processing Record 1 of Set 2 | nikolskoye
# Processing Record 2 of Set 2 | busselton
# Processing Record 3 of Set 2 | torbay
# Processing Record 4 of Set 2 | airai
# Processing Record 5 of Set 2 | arraial do cabo
# Processing Record 6 of Set 2 | quelimane
# Processing Record 7 of Set 2 | bentiu
# Processing Record 8 of Set 2 | bograd
# Processing Record 9 of Set 2 | mudigere
# Processing Record 10 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 11 of Set 2 | locri
# Processing Record 12 of Set 2 | saint-philippe
# Processing Record 13 of Set 2 | upernavik
# Processing Record 14 of Set 2 | cape town
# Processing Record 15 of Set 2 | shieli
# Processing Record 16 of Set 2 | arroyo
# Processing Record 17 of Set 2 | tabiauea
# City not found. Skipping...
# Processing Record 18 of Set 2 | sao filipe
# Processing Record 19 of Set 2 | pangnirtung
# Processing Record 20 of Set 2 | nanortalik
# Processing Record 21 of Set 2 | barrow
# Processing Record 22 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 23 of Set 2 | chokurdakh
# Processing Record 24 of Set 2 | katha
# City not found. Skipping...
# Processing Record 25 of Set 2 | uray
# Processing Record 26 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 27 of Set 2 | bredasdorp
# Processing Record 28 of Set 2 | castro
# Processing Record 29 of Set 2 | sao joao da barra
# Processing Record 30 of Set 2 | faanui
# Processing Record 31 of Set 2 | avarua
# Processing Record 32 of Set 2 | albany
# Processing Record 33 of Set 2 | jaciara
# Processing Record 34 of Set 2 | mgandu
# Processing Record 35 of Set 2 | penzance
# Processing Record 36 of Set 2 | san patricio
# Processing Record 37 of Set 2 | owando
# Processing Record 38 of Set 2 | hornepayne
# Processing Record 39 of Set 2 | areia branca
# Processing Record 40 of Set 2 | meulaboh
# Processing Record 41 of Set 2 | ilulissat
# Processing Record 42 of Set 2 | salalah
# Processing Record 43 of Set 2 | lopatino
# Processing Record 44 of Set 2 | hamilton
# Processing Record 45 of Set 2 | tasiilaq
# Processing Record 46 of Set 2 | los llanos de aridane
# Processing Record 47 of Set 2 | itarema
# Processing Record 48 of Set 2 | cayenne
# Processing Record 49 of Set 2 | nyurba
# Processing Record 50 of Set 2 | isangel
# Processing Record 1 of Set 3 | georgetown
# Processing Record 2 of Set 3 | tuktoyaktuk
# Processing Record 3 of Set 3 | manresa
# Processing Record 4 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 5 of Set 3 | saskylakh
# Processing Record 6 of Set 3 | klaksvik
# Processing Record 7 of Set 3 | sinop
# Processing Record 8 of Set 3 | tual
# Processing Record 9 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 10 of Set 3 | victoria
# Processing Record 11 of Set 3 | longyearbyen
# Processing Record 12 of Set 3 | rocha
# Processing Record 13 of Set 3 | broome
# Processing Record 14 of Set 3 | buraydah
# Processing Record 15 of Set 3 | samaipata
# Processing Record 16 of Set 3 | doha
# Processing Record 17 of Set 3 | suntar
# Processing Record 18 of Set 3 | iqaluit
# Processing Record 19 of Set 3 | labrea
# Processing Record 20 of Set 3 | chapais
# Processing Record 21 of Set 3 | rosarito
# Processing Record 22 of Set 3 | puerto ayora
# Processing Record 23 of Set 3 | burbach
# Processing Record 24 of Set 3 | rio gallegos
# Processing Record 25 of Set 3 | talcahuano
# Processing Record 26 of Set 3 | valdepenas
# Processing Record 27 of Set 3 | jambi
# Processing Record 28 of Set 3 | yaring
# Processing Record 29 of Set 3 | anadyr
# Processing Record 30 of Set 3 | bambous virieux
# Processing Record 31 of Set 3 | sioux lookout
# Processing Record 32 of Set 3 | ust-nera
# Processing Record 33 of Set 3 | vigrestad
# Processing Record 34 of Set 3 | anshun
# Processing Record 35 of Set 3 | sindor
# Processing Record 36 of Set 3 | sorvag
# City not found. Skipping...
# Processing Record 37 of Set 3 | utiroa
# City not found. Skipping...
# Processing Record 38 of Set 3 | kaitangata
# Processing Record 39 of Set 3 | yar-sale
# Processing Record 40 of Set 3 | yellowknife
# Processing Record 41 of Set 3 | saldanha
# Processing Record 42 of Set 3 | brandfort
# Processing Record 43 of Set 3 | vila
# Processing Record 44 of Set 3 | clyde river
# Processing Record 45 of Set 3 | mount isa
# Processing Record 46 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 47 of Set 3 | pochutla
# Processing Record 48 of Set 3 | saint-georges
# Processing Record 49 of Set 3 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 50 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 1 of Set 4 | yining
# Processing Record 2 of Set 4 | jumla
# Processing Record 3 of Set 4 | rapid valley
# Processing Record 4 of Set 4 | kudat
# Processing Record 5 of Set 4 | quimperle
# Processing Record 6 of Set 4 | naze
# Processing Record 7 of Set 4 | chabahar
# Processing Record 8 of Set 4 | matara
# Processing Record 9 of Set 4 | portland
# Processing Record 10 of Set 4 | vardo
# Processing Record 11 of Set 4 | port hardy
# Processing Record 12 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 13 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 14 of Set 4 | maragogi
# Processing Record 15 of Set 4 | algeciras
# Processing Record 16 of Set 4 | ennis
# Processing Record 17 of Set 4 | alotau
# City not found. Skipping...
# Processing Record 18 of Set 4 | whyalla
# Processing Record 19 of Set 4 | aklavik
# Processing Record 20 of Set 4 | mpraeso
# Processing Record 21 of Set 4 | baijiantan
# Processing Record 22 of Set 4 | bubaque
# Processing Record 23 of Set 4 | tuatapere
# Processing Record 24 of Set 4 | dudinka
# Processing Record 25 of Set 4 | vadakku valliyur
# Processing Record 26 of Set 4 | erenhot
# Processing Record 27 of Set 4 | dikson
# Processing Record 28 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 29 of Set 4 | ulladulla
# Processing Record 30 of Set 4 | omboue
# Processing Record 31 of Set 4 | puerto rondon
# Processing Record 32 of Set 4 | riberalta
# Processing Record 33 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 34 of Set 4 | souillac
# Processing Record 35 of Set 4 | palmer
# Processing Record 36 of Set 4 | komono
# Processing Record 37 of Set 4 | anchorage
# Processing Record 38 of Set 4 | baykit
# Processing Record 39 of Set 4 | marsa matruh
# Processing Record 40 of Set 4 | gunjur
# Processing Record 41 of Set 4 | vestmannaeyjar
# Processing Record 42 of Set 4 | lebu
# Processing Record 43 of Set 4 | bowen
# Processing Record 44 of Set 4 | fayaoue
# Processing Record 45 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 46 of Set 4 | rawson
# Processing Record 47 of Set 4 | broken hill
# Processing Record 48 of Set 4 | bargarh
# Processing Record 49 of Set 4 | chuy
# Processing Record 50 of Set 4 | churapcha
# Processing Record 1 of Set 5 | salsig
# Processing Record 2 of Set 5 | erzin
# Processing Record 3 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 4 of Set 5 | nouakchott
# Processing Record 5 of Set 5 | tocopilla
# Processing Record 6 of Set 5 | oum hadjer
# Processing Record 7 of Set 5 | touros
# Processing Record 8 of Set 5 | maningrida
# Processing Record 9 of Set 5 | anuradhapura
# Processing Record 10 of Set 5 | padang
# Processing Record 11 of Set 5 | talnakh
# Processing Record 12 of Set 5 | jinchang
# Processing Record 13 of Set 5 | bassar
# Processing Record 14 of Set 5 | ancud
# Processing Record 15 of Set 5 | konevo
# Processing Record 16 of Set 5 | severo-kurilsk
# Processing Record 17 of Set 5 | haines junction
# Processing Record 18 of Set 5 | grimshaw
# Processing Record 19 of Set 5 | balezino
# Processing Record 20 of Set 5 | katsuura
# Processing Record 21 of Set 5 | vila franca do campo
# Processing Record 22 of Set 5 | vila velha
# Processing Record 23 of Set 5 | mocambique
# City not found. Skipping...
# Processing Record 24 of Set 5 | mustafakemalpasa
# Processing Record 25 of Set 5 | riyadh
# Processing Record 26 of Set 5 | thompson
# Processing Record 27 of Set 5 | sutton
# Processing Record 28 of Set 5 | wenling
# Processing Record 29 of Set 5 | te anau
# Processing Record 30 of Set 5 | kassala
# Processing Record 31 of Set 5 | sao domingos do maranhao
# Processing Record 32 of Set 5 | alta floresta
# Processing Record 33 of Set 5 | mozirje
# Processing Record 34 of Set 5 | ottawa
# Processing Record 35 of Set 5 | klyuchi
# Processing Record 36 of Set 5 | coihaique
# Processing Record 37 of Set 5 | dinsor
# City not found. Skipping...
# Processing Record 38 of Set 5 | batagay-alyta
# Processing Record 39 of Set 5 | weihai
# Processing Record 40 of Set 5 | kearney
# Processing Record 41 of Set 5 | harlingen
# Processing Record 42 of Set 5 | nizwa
# Processing Record 43 of Set 5 | cabo san lucas
# Processing Record 44 of Set 5 | nouadhibou
# Processing Record 45 of Set 5 | tromso
# Processing Record 46 of Set 5 | mobai
# Processing Record 47 of Set 5 | genhe
# Processing Record 48 of Set 5 | soe
# Processing Record 49 of Set 5 | vertientes
# Processing Record 50 of Set 5 | lishui
# Processing Record 1 of Set 6 | marawi
# Processing Record 2 of Set 6 | fort saint john
# City not found. Skipping...
# Processing Record 3 of Set 6 | natal
# Processing Record 4 of Set 6 | rabo de peixe
# Processing Record 5 of Set 6 | abha
# Processing Record 6 of Set 6 | qaanaaq
# Processing Record 7 of Set 6 | santa lucia
# Processing Record 8 of Set 6 | belmonte
# Processing Record 9 of Set 6 | thiers
# Processing Record 10 of Set 6 | saint george
# Processing Record 11 of Set 6 | krasnogvardeyskiy
# Processing Record 12 of Set 6 | carutapera
# Processing Record 13 of Set 6 | kolpny
# Processing Record 14 of Set 6 | saint-pierre
# Processing Record 15 of Set 6 | zunyi
# Processing Record 16 of Set 6 | husavik
# Processing Record 17 of Set 6 | kegayli
# City not found. Skipping...
# Processing Record 18 of Set 6 | sitka
# Processing Record 19 of Set 6 | phan thiet
# Processing Record 20 of Set 6 | araouane
# Processing Record 21 of Set 6 | basoko
# Processing Record 22 of Set 6 | mahebourg
# Processing Record 23 of Set 6 | mehamn
# Processing Record 24 of Set 6 | san cristobal
# Processing Record 25 of Set 6 | hit
# Processing Record 26 of Set 6 | lensk
# Processing Record 27 of Set 6 | burica
# City not found. Skipping...
# Processing Record 28 of Set 6 | east london
# Processing Record 29 of Set 6 | swift current
# Processing Record 30 of Set 6 | kahului
# Processing Record 31 of Set 6 | neustadt
# Processing Record 32 of Set 6 | dunda
# Processing Record 33 of Set 6 | taltal
# Processing Record 34 of Set 6 | xai-xai
# Processing Record 35 of Set 6 | jurbarkas
# Processing Record 36 of Set 6 | bengkulu
# Processing Record 37 of Set 6 | villaviciosa
# Processing Record 38 of Set 6 | svetlogorsk
# Processing Record 39 of Set 6 | conceicao do araguaia
# Processing Record 40 of Set 6 | awjilah
# Processing Record 41 of Set 6 | cockburn town
# Processing Record 42 of Set 6 | hay river
# Processing Record 43 of Set 6 | kenai
# Processing Record 44 of Set 6 | murdochville
# Processing Record 45 of Set 6 | paamiut
# Processing Record 46 of Set 6 | krasnoselkup
# Processing Record 47 of Set 6 | bartow
# Processing Record 48 of Set 6 | ostrovnoy
# Processing Record 49 of Set 6 | novikovo
# Processing Record 50 of Set 6 | viesca
# Processing Record 1 of Set 7 | constitucion
# Processing Record 2 of Set 7 | sembe
# Processing Record 3 of Set 7 | buon me thuot
# City not found. Skipping...
# Processing Record 4 of Set 7 | mancio lima
# Processing Record 5 of Set 7 | kieta
# Processing Record 6 of Set 7 | lyubim
# Processing Record 7 of Set 7 | esperance
# Processing Record 8 of Set 7 | soc trang
# Processing Record 9 of Set 7 | lagoa
# Processing Record 10 of Set 7 | shitkino
# Processing Record 11 of Set 7 | port jervis
# Processing Record 12 of Set 7 | san vicente
# Processing Record 13 of Set 7 | takoradi
# Processing Record 14 of Set 7 | brigham city
# Processing Record 15 of Set 7 | hobyo
# Processing Record 16 of Set 7 | viligili
# City not found. Skipping...
# Processing Record 17 of Set 7 | melo
# Processing Record 18 of Set 7 | banfora
# Processing Record 19 of Set 7 | viedma
# Processing Record 20 of Set 7 | amarkantak
# Processing Record 21 of Set 7 | port lincoln
# Processing Record 22 of Set 7 | herat
# Processing Record 23 of Set 7 | makakilo city
# Processing Record 24 of Set 7 | pascagoula
# Processing Record 25 of Set 7 | butembo
# Processing Record 26 of Set 7 | verkhoyansk
# Processing Record 27 of Set 7 | port augusta
# Processing Record 28 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 29 of Set 7 | dekernes
# Processing Record 30 of Set 7 | atambua
# Processing Record 31 of Set 7 | whitianga
# Processing Record 32 of Set 7 | salinopolis
# Processing Record 33 of Set 7 | mount gambier
# Processing Record 34 of Set 7 | sabancuy
# Processing Record 35 of Set 7 | kavaratti
# Processing Record 36 of Set 7 | tavricheskoye
# Processing Record 37 of Set 7 | road town
# Processing Record 38 of Set 7 | lincoln
# Processing Record 39 of Set 7 | ouegoa
# Processing Record 40 of Set 7 | gawler
# Processing Record 41 of Set 7 | ugoofaaru
# Processing Record 42 of Set 7 | ust-maya
# Processing Record 43 of Set 7 | bay saint louis
# Processing Record 44 of Set 7 | that phanom
# Processing Record 45 of Set 7 | khandyga
# Processing Record 46 of Set 7 | margate
# Processing Record 47 of Set 7 | bethel
# Processing Record 48 of Set 7 | lac du bonnet
# Processing Record 49 of Set 7 | maniitsoq
# Processing Record 50 of Set 7 | pisco
# Processing Record 1 of Set 8 | kavieng
# Processing Record 2 of Set 8 | regente feijo
# Processing Record 3 of Set 8 | kommunisticheskiy
# Processing Record 4 of Set 8 | reus
# Processing Record 5 of Set 8 | yulara
# Processing Record 6 of Set 8 | hovd
# Processing Record 7 of Set 8 | winnemucca
# Processing Record 8 of Set 8 | diego de almagro
# Processing Record 9 of Set 8 | shingu
# Processing Record 10 of Set 8 | dingle
# Processing Record 11 of Set 8 | arti
# Processing Record 12 of Set 8 | santo antonio do leverger
# Processing Record 13 of Set 8 | vila do maio
# Processing Record 14 of Set 8 | ponta do sol
# Processing Record 15 of Set 8 | shakawe
# Processing Record 16 of Set 8 | vanavara
# Processing Record 17 of Set 8 | bilibino
# Processing Record 18 of Set 8 | nemuro
# Processing Record 19 of Set 8 | adrar
# Processing Record 20 of Set 8 | dubbo
# Processing Record 21 of Set 8 | yicheng
# Processing Record 22 of Set 8 | fernie
# Processing Record 23 of Set 8 | laguna
# Processing Record 24 of Set 8 | sampit
# Processing Record 25 of Set 8 | shanhetun
# Processing Record 26 of Set 8 | tutoia
# Processing Record 27 of Set 8 | ascension
# Processing Record 28 of Set 8 | meyungs
# City not found. Skipping...
# Processing Record 29 of Set 8 | gayny
# Processing Record 30 of Set 8 | perelyub
# Processing Record 31 of Set 8 | mayo
# Processing Record 32 of Set 8 | walvis bay
# Processing Record 33 of Set 8 | jalu
# Processing Record 34 of Set 8 | olafsvik
# Processing Record 35 of Set 8 | swan hill
# Processing Record 36 of Set 8 | mwense
# Processing Record 37 of Set 8 | novyy urengoy
# Processing Record 38 of Set 8 | shelburne
# Processing Record 39 of Set 8 | suluq
# Processing Record 40 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 41 of Set 8 | kandalaksha
# Processing Record 42 of Set 8 | kattivakkam
# Processing Record 43 of Set 8 | trelew
# Processing Record 44 of Set 8 | high level
# Processing Record 45 of Set 8 | isiro
# Processing Record 46 of Set 8 | moanda
# Processing Record 47 of Set 8 | kabelvag
# Processing Record 48 of Set 8 | ambulu
# Processing Record 49 of Set 8 | alice town
# Processing Record 50 of Set 8 | gravdal
# Processing Record 1 of Set 9 | yarmouth
# Processing Record 2 of Set 9 | agadez
# Processing Record 3 of Set 9 | wieliczka
# Processing Record 4 of Set 9 | saraipali
# Processing Record 5 of Set 9 | chimbote
# Processing Record 6 of Set 9 | san jose
# Processing Record 7 of Set 9 | kununurra
# Processing Record 8 of Set 9 | russell
# Processing Record 9 of Set 9 | san rafael
# Processing Record 10 of Set 9 | tateyama
# Processing Record 11 of Set 9 | bonavista
# Processing Record 12 of Set 9 | rabaul
# Processing Record 13 of Set 9 | chaozhou
# Processing Record 14 of Set 9 | teya
# Processing Record 15 of Set 9 | plonsk
# Processing Record 16 of Set 9 | lasa
# Processing Record 17 of Set 9 | otjimbingwe
# Processing Record 18 of Set 9 | grand gaube
# Processing Record 19 of Set 9 | cidreira
# Processing Record 20 of Set 9 | bluefields
# Processing Record 21 of Set 9 | qasigiannguit
# Processing Record 22 of Set 9 | mokhsogollokh
# Processing Record 23 of Set 9 | inirida
# Processing Record 24 of Set 9 | pervoavgustovskiy
# Processing Record 25 of Set 9 | codajas
# Processing Record 26 of Set 9 | hohhot
# Processing Record 27 of Set 9 | shchelyayur
# City not found. Skipping...
# Processing Record 28 of Set 9 | kaifeng
# Processing Record 29 of Set 9 | inuvik
# Processing Record 30 of Set 9 | toliary
# City not found. Skipping...
# Processing Record 31 of Set 9 | maldonado
# Processing Record 32 of Set 9 | luanda
# Processing Record 33 of Set 9 | namibe
# Processing Record 34 of Set 9 | houma
# Processing Record 35 of Set 9 | santa ana
# Processing Record 36 of Set 9 | itaituba
# Processing Record 37 of Set 9 | borogontsy
# Processing Record 38 of Set 9 | amazar
# Processing Record 39 of Set 9 | revda
# Processing Record 40 of Set 9 | tuy hoa
# Processing Record 41 of Set 9 | tomigusuku
# Processing Record 42 of Set 9 | santa maria
# Processing Record 43 of Set 9 | ust-uda
# Processing Record 44 of Set 9 | fortuna
# Processing Record 45 of Set 9 | oxelosund
# Processing Record 46 of Set 9 | baoying
# Processing Record 47 of Set 9 | kupang
# Processing Record 48 of Set 9 | tautira
# Processing Record 49 of Set 9 | rudbar
# Processing Record 50 of Set 9 | asind
# Processing Record 1 of Set 10 | chihuahua
# Processing Record 2 of Set 10 | manica
# Processing Record 3 of Set 10 | saint-francois
# Processing Record 4 of Set 10 | lorengau
# Processing Record 5 of Set 10 | nizhneyansk
# City not found. Skipping...
# Processing Record 6 of Set 10 | rassvet
# Processing Record 7 of Set 10 | perama
# Processing Record 8 of Set 10 | nador
# Processing Record 9 of Set 10 | goderich
# Processing Record 10 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 11 of Set 10 | san andres
# Processing Record 12 of Set 10 | fallon
# Processing Record 13 of Set 10 | bull savanna
# Processing Record 14 of Set 10 | zlatoustovsk
# City not found. Skipping...
# Processing Record 15 of Set 10 | presidencia roque saenz pena
# Processing Record 16 of Set 10 | porto velho
# Processing Record 17 of Set 10 | igrim
# Processing Record 18 of Set 10 | narsaq
# Processing Record 19 of Set 10 | semey
# Processing Record 20 of Set 10 | abu dhabi
# Processing Record 21 of Set 10 | coquimbo
# Processing Record 22 of Set 10 | mchinji
# Processing Record 23 of Set 10 | bijie
# Processing Record 24 of Set 10 | weyburn
# Processing Record 25 of Set 10 | novska
# Processing Record 26 of Set 10 | tabory
# Processing Record 27 of Set 10 | rokytne
# Processing Record 28 of Set 10 | saint-paul
# Processing Record 29 of Set 10 | zaysan
# Processing Record 30 of Set 10 | omaruru
# Processing Record 31 of Set 10 | ust-ishim
# Processing Record 32 of Set 10 | gandajika
# Processing Record 33 of Set 10 | benguela
# Processing Record 34 of Set 10 | hofn
# Processing Record 35 of Set 10 | urbano santos
# Processing Record 36 of Set 10 | ahar
# Processing Record 37 of Set 10 | kosonsoy
# Processing Record 38 of Set 10 | belaya gora
# Processing Record 39 of Set 10 | alyangula
# Processing Record 40 of Set 10 | zheleznodorozhnyy
# Processing Record 41 of Set 10 | nebaj
# Processing Record 42 of Set 10 | buala
# Processing Record 43 of Set 10 | karkaralinsk
# City not found. Skipping...
# Processing Record 44 of Set 10 | quatre cocos
# Processing Record 45 of Set 10 | kharitonovo
# Processing Record 46 of Set 10 | chulman
# Processing Record 47 of Set 10 | piranhas
# Processing Record 48 of Set 10 | taganak
# Processing Record 49 of Set 10 | mareeba
# Processing Record 50 of Set 10 | leshukonskoye
# Processing Record 1 of Set 11 | nasirabad
# Processing Record 2 of Set 11 | strezhevoy
# Processing Record 3 of Set 11 | hami
# Processing Record 4 of Set 11 | emerald
# Processing Record 5 of Set 11 | roald
# Processing Record 6 of Set 11 | ceres
# Processing Record 7 of Set 11 | chagda
# City not found. Skipping...
# Processing Record 8 of Set 11 | port blair
# Processing Record 9 of Set 11 | oistins
# Processing Record 10 of Set 11 | port shepstone
# Processing Record 11 of Set 11 | atbasar
# Processing Record 12 of Set 11 | iberia
# Processing Record 13 of Set 11 | saint anthony
# Processing Record 14 of Set 11 | ferme-neuve
# Processing Record 15 of Set 11 | mukhen
# Processing Record 16 of Set 11 | bandarbeyla
# Processing Record 17 of Set 11 | kutum
# Processing Record 18 of Set 11 | ciudad bolivar
# Processing Record 19 of Set 11 | mogadishu
# Processing Record 20 of Set 11 | wiang sa
# Processing Record 21 of Set 11 | shirokiy
# Processing Record 22 of Set 11 | esik
# Processing Record 23 of Set 11 | dunedin
# Processing Record 24 of Set 11 | cacahoatan
# Processing Record 25 of Set 11 | kharp
# Processing Record 26 of Set 11 | kapiri mposhi
# Processing Record 27 of Set 11 | udachnyy
# Processing Record 28 of Set 11 | arman
# Processing Record 29 of Set 11 | udalguri
# Processing Record 30 of Set 11 | arawa
# Processing Record 31 of Set 11 | nisia floresta
# Processing Record 32 of Set 11 | caibarien
# Processing Record 33 of Set 11 | kaura namoda
# Processing Record 34 of Set 11 | hambantota
# Processing Record 35 of Set 11 | chalus
# Processing Record 36 of Set 11 | champerico
# Processing Record 37 of Set 11 | kouroussa
# Processing Record 38 of Set 11 | nuuk
# Processing Record 39 of Set 11 | guerrero negro
# Processing Record 40 of Set 11 | morehead
# Processing Record 41 of Set 11 | camacupa
# Processing Record 42 of Set 11 | imperial
# Processing Record 43 of Set 11 | sanchor
# Processing Record 44 of Set 11 | baturite
# Processing Record 45 of Set 11 | lavrentiya
# Processing Record 46 of Set 11 | north bend
# Processing Record 47 of Set 11 | stavern
# Processing Record 48 of Set 11 | imbituba
# Processing Record 49 of Set 11 | palestine
# Processing Record 50 of Set 11 | naryan-mar
# Processing Record 1 of Set 12 | lircay
# Processing Record 2 of Set 12 | sao gabriel da cachoeira
# Processing Record 3 of Set 12 | caravelas
# Processing Record 4 of Set 12 | poum
# Processing Record 5 of Set 12 | ahuimanu
# Processing Record 6 of Set 12 | cascais
# Processing Record 7 of Set 12 | novobirilyussy
# Processing Record 8 of Set 12 | dolinsk
# Processing Record 9 of Set 12 | zalantun
# Processing Record 10 of Set 12 | tias
# Processing Record 11 of Set 12 | basco
# Processing Record 12 of Set 12 | bud
# Processing Record 13 of Set 12 | ambikapur
# Processing Record 14 of Set 12 | winston
# Processing Record 15 of Set 12 | normandin
# Processing Record 16 of Set 12 | voi
# Processing Record 17 of Set 12 | kirakira
# Processing Record 18 of Set 12 | kaili
# Processing Record 19 of Set 12 | ulaanbaatar
# Processing Record 20 of Set 12 | ningyang
# Processing Record 21 of Set 12 | saint-denis
# Processing Record 22 of Set 12 | tiksi
# Processing Record 23 of Set 12 | yinchuan
# Processing Record 24 of Set 12 | vitim
# Processing Record 25 of Set 12 | doba
# Processing Record 26 of Set 12 | tosham
# Processing Record 27 of Set 12 | zhangjiakou
# Processing Record 28 of Set 12 | sinnamary
# Processing Record 29 of Set 12 | santiago
# Processing Record 30 of Set 12 | podor
# Processing Record 31 of Set 12 | batagay
# Processing Record 32 of Set 12 | jaguarari
# Processing Record 33 of Set 12 | voh
# Processing Record 34 of Set 12 | mitsamiouli
# Processing Record 35 of Set 12 | kantunilkin
# Processing Record 36 of Set 12 | sarh
# Processing Record 37 of Set 12 | nyaunglebin
# Processing Record 38 of Set 12 | skibbereen
# Processing Record 39 of Set 12 | artyk
# City not found. Skipping...
# Processing Record 40 of Set 12 | mlowo
# Processing Record 41 of Set 12 | mombetsu
# Processing Record 42 of Set 12 | anloga
# Processing Record 43 of Set 12 | codrington
# Processing Record 44 of Set 12 | tiznit
# Processing Record 45 of Set 12 | hvide sande
# Processing Record 46 of Set 12 | itupiranga
# Processing Record 47 of Set 12 | poltavka
# Processing Record 48 of Set 12 | buariki
# City not found. Skipping...
# Processing Record 49 of Set 12 | san quintin
# Processing Record 50 of Set 12 | one hundred mile house
# City not found. Skipping...
# Processing Record 1 of Set 13 | leningradskiy
# Processing Record 2 of Set 13 | lompoc
# Processing Record 3 of Set 13 | kendari
# Processing Record 4 of Set 13 | ilembo
# Processing Record 5 of Set 13 | dicabisagan
# Processing Record 6 of Set 13 | skalistyy
# City not found. Skipping...
# Processing Record 7 of Set 13 | costa rica
# Processing Record 8 of Set 13 | steamboat springs
# Processing Record 9 of Set 13 | dakar
# Processing Record 10 of Set 13 | sisimiut
# Processing Record 11 of Set 13 | skagastrond
# City not found. Skipping...
# Processing Record 12 of Set 13 | sturgis
# Processing Record 13 of Set 13 | mayachnyy
# Processing Record 14 of Set 13 | ziarat
# Processing Record 15 of Set 13 | bakchar
# Processing Record 16 of Set 13 | sibu
# Processing Record 17 of Set 13 | boa vista
# Processing Record 18 of Set 13 | nikel
# Processing Record 19 of Set 13 | khandagayty
# Processing Record 20 of Set 13 | kuche
# City not found. Skipping...
# Processing Record 21 of Set 13 | pahrump
# Processing Record 22 of Set 13 | vao
# Processing Record 23 of Set 13 | praia
# Processing Record 24 of Set 13 | manta
# Processing Record 25 of Set 13 | darnah
# Processing Record 26 of Set 13 | garissa
# Processing Record 27 of Set 13 | palana
# Processing Record 28 of Set 13 | kiruna
# Processing Record 29 of Set 13 | grand baie
# Processing Record 30 of Set 13 | harper
# Processing Record 31 of Set 13 | kamenskoye
# City not found. Skipping...
# Processing Record 32 of Set 13 | wetaskiwin
# Processing Record 33 of Set 13 | fairbanks
# Processing Record 34 of Set 13 | namatanai
# Processing Record 35 of Set 13 | chicama
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
import pandas as pd

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0              Mkushi -13.6202   29.3939     87.85        26          45
# 1               Kapaa  22.0752 -159.3190     75.52        85          75
# 2             Yahotyn  50.2798   31.7625     38.91        78         100
# 3             Rikitea -23.1203 -134.9692     75.06        78          13
# 4               Vaini -21.2000 -175.2000     77.16        88          40
# 5              Hobart -42.8794  147.3294     58.01        90          90
# 6               Bluff -46.6000  168.3333     55.80        94         100
# 7        Norman Wells  65.2820 -126.8329    -18.31        95         100
# 8  Sao Felix Do Xingu  -6.6447  -51.9950     81.61        78          85
# 9             Mataura -46.1927  168.8643     55.47        89         100
#
#    Wind Speed Country                 Date
# 0        6.42      ZM  2021-12-02 14:12:14
# 1       12.66      US  2021-12-02 14:12:14
# 2       13.38      UA  2021-12-02 14:12:14
# 3       18.39      PF  2021-12-02 14:12:15
# 4        5.75      TO  2021-12-02 14:12:15
# 5        7.00      AU  2021-12-02 14:10:31
# 6        2.84      NZ  2021-12-02 14:12:15
# 7       10.16      CA  2021-12-02 14:12:15
# 8        2.71      BR  2021-12-02 14:11:16
# 9        1.16      NZ  2021-12-02 14:12:16

# %%
#Reorder the columns
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#                  City Country                 Date      Lat       Lng  \
# 0              Mkushi      ZM  2021-12-02 14:12:14 -13.6202   29.3939
# 1               Kapaa      US  2021-12-02 14:12:14  22.0752 -159.3190
# 2             Yahotyn      UA  2021-12-02 14:12:14  50.2798   31.7625
# 3             Rikitea      PF  2021-12-02 14:12:15 -23.1203 -134.9692
# 4               Vaini      TO  2021-12-02 14:12:15 -21.2000 -175.2000
# 5              Hobart      AU  2021-12-02 14:10:31 -42.8794  147.3294
# 6               Bluff      NZ  2021-12-02 14:12:15 -46.6000  168.3333
# 7        Norman Wells      CA  2021-12-02 14:12:15  65.2820 -126.8329
# 8  Sao Felix Do Xingu      BR  2021-12-02 14:11:16  -6.6447  -51.9950
# 9             Mataura      NZ  2021-12-02 14:12:16 -46.1927  168.8643
#
#    Max Temp  Humidity  Cloudiness  Wind Speed
# 0     87.85        26          45        6.42
# 1     75.52        85          75       12.66
# 2     38.91        78         100       13.38
# 3     75.06        78          13       18.39
# 4     77.16        88          40        5.75
# 5     58.01        90          90        7.00
# 6     55.80        94         100        2.84
# 7    -18.31        95         100       10.16
# 8     81.61        78          85        2.71
# 9     55.47        89         100        1.16

# %%
#Create the output file (CSV)
output_data_file = "weather_data/cities.csv"

#Export the city_data into a CSV
city_data_df.to_csv(output_data_file, index_label='City_ID')

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Import the time module.
import time
# Get today's date in seconds.
today = time.strftime("%x")
today
# Out:
# '12/02/21'

# %%
import matplotlib.pyplot as plt

# %%
# Import time module
import time

# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig1.png")

# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. humidity.
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig2.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. cloudiness.
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig3.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. wind speed.
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig4.png")
# Show plot.
plt.show()

# %%
#Import linregress
from scipy.stats import linregress

#Create a function to perform linear regression on the weather data and plot a regression line with the equation
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):
    
    #Run regression on hemisphere weather data
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)
    
    #Calculate the regression line "y values" from the slope and intercept
    regress_values = x_values * slope + intercept
    #Get the equation of the line
    line_eq = "y = " + str(round(slope,2)) + "x + " +str(round(intercept,2))
    
    #Create a scatter plot and plot the regression line
    plt.scatter(x_values, y_values)
    plt.plot(x_values, regress_values, "r")
    
    #Annotate the text for the line equation
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.title(title)
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.show()

# %%
#Create Northern and Southern Hemisphere data frames
northern_hemi_df = city_data_df.loc[(city_data_df['Lat'] >= 0)]
southern_hemi_df = city_data_df.loc[(city_data_df['Lat'] < 0)]

northern_hemi_df.head()
# Out:
#             City Country                 Date      Lat       Lng  Max Temp  \
# 1          Kapaa      US  2021-12-02 14:12:14  22.0752 -159.3190     75.52
# 2        Yahotyn      UA  2021-12-02 14:12:14  50.2798   31.7625     38.91
# 7   Norman Wells      CA  2021-12-02 14:12:15  65.2820 -126.8329    -18.31
# 12    The Valley      AI  2021-12-02 14:12:16  18.2170  -63.0578     84.34
# 13   Brandenburg      DE  2021-12-02 14:12:17  52.4167   12.5500     39.96
#
#     Humidity  Cloudiness  Wind Speed
# 1         85          75       12.66
# 2         78         100       13.38
# 7         95         100       10.16
# 12        70          40       14.97
# 13        62           3       10.71

# %%
#Linear regression on the Northern Hemisphere (Max Temp)
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Max Temp']

#Call the function
plot_linear_regression(x_values, y_values, 'Linear Regression on the Northern Hemisphere \n for Maximum Temperature', 
                       'Max Temp', (10,40))

# %%
#Linear regression on the Southern Hemisphere (Max Temp)
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Max Temp']

#Call the function
plot_linear_regression(x_values, y_values, 'Linear Regression on the Southern Hemisphere \n for Maximum Temperature', 
                       'Max Temp', (-50,90))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for % Humidity', '% Humidity',(40,10))

# %%
#Linear regression on the Southern Hemisphere (Humidity)
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Humidity']

#Call the function
plot_linear_regression(x_values, y_values, 'Linear Regression on the Southern Hemisphere \n for % Humidity', 
                       '% Humidity', (-50,15))

# %%
#Linear regression on the Northern Hemisphere (Cloudiness)
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Cloudiness']

#Call the function
plot_linear_regression(x_values, y_values, 'Linear Regression on the Northern Hemisphere \n for % Cloudiness', 
                       '% Cloudiness', (10,60))

# %%
#Linear regression on the Southern Hemisphere (Cloudiness)
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Cloudiness']

#Call the function
plot_linear_regression(x_values, y_values, 'Linear Regression on the Southern Hemisphere \n for % Cloudiness', 
                       '% Cloudiness', (-50,60))

# %%
#Linear regression on the Northern Hemisphere (Wind Speed)
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Wind Speed']

#Call the function
plot_linear_regression(x_values, y_values, 'Linear Regression on the Northern Hemisphere \n for Wind Speed', 
                       'Wind Speed', (40,35))

# %%
#Linear regression on the Southern Hemisphere (Wind Speed)
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Wind Speed']

#Call the function
plot_linear_regression(x_values, y_values, 'Linear Regression on the Southern Hemisphere \n for Wind Speed', 
                       'Wind Speed', (-50,15))
